# %%
import os
import glob
import pandas as pd

#create a dictionary to hold data frames
df_dict = {}

output_file = 'combined/lineup_data.csv'

for season_type in ['Regular Season', 'Playoffs']:
    
    #get csv files to read
    folder_path = season_type
    csv_files = glob.glob(os.path.join(folder_path,'*.csv'))
    
    # Initialize an empty list to hold df's
    df_list = []
    
    #loop over csv files
    for csv_file in csv_files:
        
        df = pd.read_csv(csv_file)
        
        #create columns for season
        season_name = csv_file.split("_")[2]
        season_strt_yr = int(season_name.split("-")[0])
        season_end_yr = int(season_strt_yr +1)
        df['SeasonName'] = season_name
        df['SeasonStrtYr'] = season_strt_yr
        df['SeasonEndYr'] = season_end_yr
        df['SeasonType'] = season_type
        
        #append dfs in a list
        df_list.append(df)
    
    #group together with pd.concat for better performance
    df_dict[season_type] = pd.concat(df_list, ignore_index=True)

all_data = pd.concat([df_dict['Regular Season'],df_dict['Playoffs']], ignore_index=True)

# Update the column order
cols = all_data.columns
season_col = ['SeasonName','SeasonStrtYr','SeasonEndYr','SeasonType']
new_order = list(cols[0:6]) + season_col
new_order = new_order + [col for col in cols if col not in new_order]
all_data = all_data[new_order]

#Split Name into 5 fields
all_data[['PlayerOne','PlayerTwo','PlayerThree','PlayerFour','PlayerFive']] = all_data['Name'].str.split(', ', expand=True)

all_data.to_csv(output_file, index = False)

# %%
lineup_data = all_data

# Read in player height csv
player_info = pd.read_csv("all_seasons.csv")
player_height = player_info[['player_name','season','player_height']]

# Join data with player height
for player in ['PlayerOne','PlayerTwo','PlayerThree','PlayerFour','PlayerFive']:
    lineup_data = pd.merge(lineup_data, player_height, left_on = [player,'SeasonName'],
                           right_on = ['player_name','season'], how = 'left', suffixes = ('',player))

# Rename Columns and remove unnecessary ones
lineup_data = lineup_data.rename(columns = {'player_height':'PlayerOneHeight',
                                           'player_heightPlayerTwo':'PlayerTwoHeight',
                                           'player_heightPlayerThree':'PlayerThreeHeight',
                                           'player_heightPlayerFour':'PlayerFourHeight',
                                           'player_heightPlayerFive':'PlayerFiveHeight'})

columns = ['EntityId','Name','TeamAbbreviation','SeasonName','SeasonEndYr','SeasonType','SecondsPlayed',
          'PlayerOne','PlayerOneHeight','PlayerTwo','PlayerTwoHeight','PlayerThree','PlayerThreeHeight',
           'PlayerFour','PlayerFourHeight','PlayerFive','PlayerFiveHeight']
lineup_data = lineup_data[columns]

# %%
lineup_data=all_data[['EntityId','Name','TeamAbbreviation','SeasonName','SeasonEndYr','SeasonType','SecondsPlayed',
          'PlayerOne','PlayerTwo','PlayerThree',
           'PlayerFour','PlayerFive']]
test = pd.melt(lineup_data,id_vars = ['EntityId','Name','TeamAbbreviation','SeasonName','SeasonEndYr','SeasonType','SecondsPlayed'],
                     var_name="Player", value_name = 'PlayerName')
test = pd.merge(test, player_height, left_on = ['PlayerName','SeasonName'],
                           right_on = ['player_name','season'], how = 'left')
test = test.sort_values(by = ['EntityId','player_height'], ascending = [True,False])
test
# Out:
#                          EntityId  \
# 1004088  1000-1005-1508-1509-1883
# 702553   1000-1005-1508-1509-1883
# 401017   1000-1005-1508-1509-1883
# 99405    1000-1005-1508-1509-1883
# 1305646  1000-1005-1508-1509-1883
# ...                           ...
# 856136        915-952-958-960-962
# 1459229       915-952-958-960-962
# 554580        915-952-958-960-962
# 252965        915-952-958-960-962
# 1157697       915-952-958-960-962
#
#                                                       Name TeamAbbreviation  \
# 1004088  Shandon Anderson, Walt Williams, Maurice Taylo...              HOU
# 702553   Shandon Anderson, Walt Williams, Maurice Taylo...              HOU
# 401017   Shandon Anderson, Walt Williams, Maurice Taylo...              HOU
# 99405    Shandon Anderson, Walt Williams, Maurice Taylo...              HOU
# 1305646  Shandon Anderson, Walt Williams, Maurice Taylo...              HOU
# ...                                                    ...              ...
# 856136   Rodney Rogers, Antoine Walker, Vitaly Potapenk...              BOS
# 1459229  Rodney Rogers, Antoine Walker, Vitaly Potapenk...              BOS
# 554580   Rodney Rogers, Antoine Walker, Vitaly Potapenk...              BOS
# 252965   Rodney Rogers, Antoine Walker, Vitaly Potapenk...              BOS
# 1157697  Rodney Rogers, Antoine Walker, Vitaly Potapenk...              BOS
#
#         SeasonName  SeasonEndYr      SeasonType  SecondsPlayed       Player  \
# 1004088    2000-01         2001  Regular Season          307.0   PlayerFour
# 702553     2000-01         2001  Regular Season          307.0  PlayerThree
# 401017     2000-01         2001  Regular Season          307.0    PlayerTwo
# 99405      2000-01         2001  Regular Season          307.0    PlayerOne
# 1305646    2000-01         2001  Regular Season          307.0   PlayerFive
# ...            ...          ...             ...            ...          ...
# 856136     2001-02         2002  Regular Season           69.0  PlayerThree
# 1459229    2001-02         2002  Regular Season           69.0   PlayerFive
# 554580     2001-02         2002  Regular Season           69.0    PlayerTwo
# 252965     2001-02         2002  Regular Season           69.0    PlayerOne
# 1157697    2001-02         2002  Regular Season           69.0   PlayerFour
#
#                PlayerName       player_name   season  player_height
# 1004088       Kelvin Cato       Kelvin Cato  2000-01         210.82
# 702553     Maurice Taylor    Maurice Taylor  2000-01         205.74
# 401017      Walt Williams     Walt Williams  2000-01         203.20
# 99405    Shandon Anderson  Shandon Anderson  2000-01         198.12
# 1305646     Steve Francis     Steve Francis  2000-01         190.50
# ...                   ...               ...      ...            ...
# 856136   Vitaly Potapenko  Vitaly Potapenko  2001-02         208.28
# 1459229    Walter McCarty    Walter McCarty  2001-02         208.28
# 554580     Antoine Walker    Antoine Walker  2001-02         205.74
# 252965      Rodney Rogers     Rodney Rogers  2001-02         200.66
# 1157697         Tony Delk         Tony Delk  2001-02         187.96
#
# [1507860 rows x 12 columns]

# %%
badNames = test.loc[test['player_height'].isna()]
badNames = badNames[['SeasonName','PlayerName','player_height']]
badNames = badNames.drop_duplicates()
badNames
# Out:
#         SeasonName           PlayerName  player_height
# 1053989    2017-18            PJ Tucker            NaN
# 1028504    2018-19            PJ Tucker            NaN
# 1498658    2015-16        Dorell Wright            NaN
# 590284     2012-13         Dwayne Jones            NaN
# 900551     2017-18            Ty Lawson            NaN
# 591059     2012-13        Tracy McGrady            NaN
# 1032646    2018-19           Kevin Knox            NaN
# 967027     2016-17     Juan Hernangomez            NaN
# 1414096    2021-22       Xavier Tillman            NaN
# 1497949    2015-16         John Holland            NaN
# 1195646    2022-23     Tristan Thompson            NaN
# 1111584    2021-22   Brandon Boston Jr.            NaN
# 815296     2021-22            MJ Walker            NaN
# 713750     2019-20              TJ Leaf            NaN
# 1473124    2022-23  Patrick Baldwin Jr.            NaN
# 1326128    2018-19        Marcus Morris            NaN
# 1502512    2017-18        Marcus Morris            NaN
# 110443     2019-20      Michael Frazier            NaN
# 1312417    2019-20    Charles Brown Jr.            NaN
# 1183422    2019-20         Jaylen Adams            NaN
# 422644     2018-19     Walter Lemon Jr.            NaN
# 152587     2017-18     Walter Lemon Jr.            NaN
# 592914     2022-23      DaQuan Jeffries            NaN
# 1115075    2021-22   Aleksej Pokusevski            NaN
# 1186596    2021-22         Luca Vildoza            NaN
# 773143     2002-03                Nene             NaN

# %%
condition1 = player_height['player_name'].str.contains('Tucker')
condition2 = player_height['season'] == '2017-18'
player_height[condition1 & condition2]
# Out:
#       player_name   season  player_height
# 9790  P.J. Tucker  2017-18         198.12

# %%
# Updates to be made:
# PJ Tucker = P.J. Tucker
# Kevin Knox = Kevin Knox II
# Juan Hernangomez = Juancho
# Xavier Tillman = Xavier Tillman Sr.
# Patrick Baldwin = Patrick Baldwin Jr


# Players only playing playoffs
# Dorell Wright played in playoffs. Should copy 2014-2015 version
# Dwayne Jones only played in playoffs. Copy 2009-2010
# Ty Lawson only playoffs. Copy 2016-17
# Tmac
#John Holland, Tristan Thompson
# Out:
# Original DataFrame:
#    ID     Name  Math_Score  English_Score
# 0   1    Alice          90             88
# 1   2      Bob          85             92
# 2   3  Charlie          95             89
#
# Reshaped DataFrame:
#    ID     Name        Subject  Score
# 0   1    Alice     Math_Score     90
# 1   2      Bob     Math_Score     85
# 2   3  Charlie     Math_Score     95
# 3   1    Alice  English_Score     88
# 4   2      Bob  English_Score     92
# 5   3  Charlie  English_Score     89

# %%
condition1 = test['PlayerName'].str.contains('Patrick Baldwin Jr.')
condition2 = test['SeasonName'] == '2022-23'
condition3 = test['SeasonType'] == 'Playoffs'
test[condition1 & condition2]



#815296	2021-22	MJ Walker	NaN
#713750	2019-20	TJ Leaf	NaN
#1326128	2018-19	Marcus Morris	NaN
#1502512	2017-18	Marcus Morris	NaN
#110443	2019-20	Michael Frazier	NaN
#1312417	2019-20	Charles Brown Jr.	NaN
#1183422	2019-20	Jaylen Adams	NaN
#422644	2018-19	Walter Lemon Jr.	NaN
#152587	2017-18	Walter Lemon Jr.	NaN
#592914	2022-23	DaQuan Jeffries	NaN
#1115075	2021-22	Aleksej Pokusevski	NaN
#1186596	2021-22	Luca Vildoza	NaN
#773143	2002-03	Nene	NaN
# Out:
#                                         EntityId  \
# 1473124  1626172-1628978-1629660-1630237-1631116
# 1171363   1626172-1628978-1629660-1631116-202691
# 1472930  1626172-1628978-1629673-1630228-1631116
# 1472997  1626172-1628978-1629673-1630237-1631116
# 1473156  1626172-1628978-1629673-1630541-1631116
# 1171630   1626172-1628978-1629673-1631116-202691
# 1171403   1626172-1628978-1629673-1631116-203110
# 1473148  1626172-1629660-1629673-1630237-1631116
# 1473099  1626172-1629660-1629673-1630541-1631116
# 1472893  1626172-1629660-1630228-1630541-1631116
# 1472949  1626172-1629660-1630237-1630541-1631116
# 1171489   1626172-1629660-1630541-1631116-203952
# 1473159  1626172-1629673-1630237-1630541-1631116
# 870064    1626172-1629673-1631116-1631157-203210
# 1473189  1627780-1628978-1630237-1630541-1631116
# 1171436  1627780-1630237-1630541-1631116-1631311
# 1171396   1628978-1629660-1629673-1631116-203110
# 1171467   1628978-1629660-1629673-1631116-203210
# 1473160  1628978-1629660-1630237-1630541-1631116
# 1171712   1628978-1629660-1630237-1631116-202691
# 1171549   1628978-1629660-1630237-1631116-203952
# 1171565  1628978-1629660-1630541-1631116-1631157
# 1171700   1628978-1629660-1630541-1631116-203110
# 869978     1628978-1629660-1631116-202691-203110
# 870076     1628978-1629660-1631116-202691-203210
# 1473149  1628978-1629673-1630228-1630541-1631116
# 1171588   1628978-1629673-1630228-1631116-203110
# 1171671   1628978-1629673-1630228-1631116-203210
# 1473023  1628978-1629673-1630237-1630541-1631116
# 1171422   1628978-1629673-1630237-1631116-203110
# 1171574   1628978-1629673-1630237-1631116-203210
# 1171512   1628978-1629673-1630541-1631116-203210
# 869921     1628978-1629673-1631116-202691-203110
# 1472904  1628978-1630228-1630237-1630541-1631116
# 568564      1628978-1631116-201939-203110-203210
# 1473171  1629660-1629673-1630164-1630228-1631116
# 1473070  1629660-1629673-1630237-1630541-1631116
# 1171354   1629660-1629673-1630237-1631116-203110
# 1171535   1629660-1629673-1630237-1631116-203210
# 1171339   1629660-1629673-1630541-1631116-203110
# 1171479   1629660-1629673-1630541-1631116-203210
# 869979     1629660-1629673-1631116-203110-203210
# 870118       1629660-1629673-1631116-203110-2738
# 1473006  1629660-1630164-1630228-1630237-1631116
# 1472889  1629660-1630164-1630237-1630541-1631116
# 1171548  1629660-1630164-1630541-1631116-1631157
# 1472791  1629660-1630228-1630237-1630541-1631116
# 1171437  1629660-1630228-1630237-1631116-1631157
# 1171605  1629660-1630237-1630541-1631116-1631311
# 1171507   1629660-1630237-1630541-1631116-203210
# 870134     1629660-1630237-1631116-202691-203210
# 568273        1629660-1631116-201939-203110-2738
# 1171521   1629673-1630164-1630228-1631116-203110
# 1472971  1629673-1630228-1630237-1630541-1631116
# 568375      1629673-1631116-201939-203110-203210
# 1171352  1630164-1630228-1630541-1631116-1631157
# 1171358  1630164-1630237-1630541-1631116-1631157
# 1171351  1630228-1630237-1630541-1631116-1631157
# 1171334  1630228-1630237-1630541-1631116-1631311
#
#                                                       Name TeamAbbreviation  \
# 1473124  Kevon Looney, Donte DiVincenzo, Ty Jerome, Ant...              GSW
# 1171363  Kevon Looney, Donte DiVincenzo, Ty Jerome, Pat...              GSW
# 1472930  Kevon Looney, Donte DiVincenzo, Jordan Poole, ...              GSW
# 1472997  Kevon Looney, Donte DiVincenzo, Jordan Poole, ...              GSW
# 1473156  Kevon Looney, Donte DiVincenzo, Jordan Poole, ...              GSW
# 1171630  Kevon Looney, Donte DiVincenzo, Jordan Poole, ...              GSW
# 1171403  Kevon Looney, Donte DiVincenzo, Jordan Poole, ...              GSW
# 1473148  Kevon Looney, Ty Jerome, Jordan Poole, Anthony...              GSW
# 1473099  Kevon Looney, Ty Jerome, Jordan Poole, Moses M...              GSW
# 1472893  Kevon Looney, Ty Jerome, Jonathan Kuminga, Mos...              GSW
# 1472949  Kevon Looney, Ty Jerome, Anthony Lamb, Moses M...              GSW
# 1171489  Kevon Looney, Ty Jerome, Moses Moody, Patrick ...              GSW
# 1473159  Kevon Looney, Jordan Poole, Anthony Lamb, Mose...              GSW
# 870064   Kevon Looney, Jordan Poole, Patrick Baldwin Jr...              GSW
# 1473189  Gary Payton II, Donte DiVincenzo, Anthony Lamb...              GSW
# 1171436  Gary Payton II, Anthony Lamb, Moses Moody, Pat...              GSW
# 1171396  Donte DiVincenzo, Ty Jerome, Jordan Poole, Pat...              GSW
# 1171467  Donte DiVincenzo, Ty Jerome, Jordan Poole, Pat...              GSW
# 1473160  Donte DiVincenzo, Ty Jerome, Anthony Lamb, Mos...              GSW
# 1171712  Donte DiVincenzo, Ty Jerome, Anthony Lamb, Pat...              GSW
# 1171549  Donte DiVincenzo, Ty Jerome, Anthony Lamb, Pat...              GSW
# 1171565  Donte DiVincenzo, Ty Jerome, Moses Moody, Patr...              GSW
# 1171700  Donte DiVincenzo, Ty Jerome, Moses Moody, Patr...              GSW
# 869978   Donte DiVincenzo, Ty Jerome, Patrick Baldwin J...              GSW
# 870076   Donte DiVincenzo, Ty Jerome, Patrick Baldwin J...              GSW
# 1473149  Donte DiVincenzo, Jordan Poole, Jonathan Kumin...              GSW
# 1171588  Donte DiVincenzo, Jordan Poole, Jonathan Kumin...              GSW
# 1171671  Donte DiVincenzo, Jordan Poole, Jonathan Kumin...              GSW
# 1473023  Donte DiVincenzo, Jordan Poole, Anthony Lamb, ...              GSW
# 1171422  Donte DiVincenzo, Jordan Poole, Anthony Lamb, ...              GSW
# 1171574  Donte DiVincenzo, Jordan Poole, Anthony Lamb, ...              GSW
# 1171512  Donte DiVincenzo, Jordan Poole, Moses Moody, P...              GSW
# 869921   Donte DiVincenzo, Jordan Poole, Patrick Baldwi...              GSW
# 1472904  Donte DiVincenzo, Jonathan Kuminga, Anthony La...              GSW
# 568564   Donte DiVincenzo, Patrick Baldwin Jr., Stephen...              GSW
# 1473171  Ty Jerome, Jordan Poole, James Wiseman, Jonath...              GSW
# 1473070  Ty Jerome, Jordan Poole, Anthony Lamb, Moses M...              GSW
# 1171354  Ty Jerome, Jordan Poole, Anthony Lamb, Patrick...              GSW
# 1171535  Ty Jerome, Jordan Poole, Anthony Lamb, Patrick...              GSW
# 1171339  Ty Jerome, Jordan Poole, Moses Moody, Patrick ...              GSW
# 1171479  Ty Jerome, Jordan Poole, Moses Moody, Patrick ...              GSW
# 869979   Ty Jerome, Jordan Poole, Patrick Baldwin Jr., ...              GSW
# 870118   Ty Jerome, Jordan Poole, Patrick Baldwin Jr., ...              GSW
# 1473006  Ty Jerome, James Wiseman, Jonathan Kuminga, An...              GSW
# 1472889  Ty Jerome, James Wiseman, Anthony Lamb, Moses ...              GSW
# 1171548  Ty Jerome, James Wiseman, Moses Moody, Patrick...              GSW
# 1472791  Ty Jerome, Jonathan Kuminga, Anthony Lamb, Mos...              GSW
# 1171437  Ty Jerome, Jonathan Kuminga, Anthony Lamb, Pat...              GSW
# 1171605  Ty Jerome, Anthony Lamb, Moses Moody, Patrick ...              GSW
# 1171507  Ty Jerome, Anthony Lamb, Moses Moody, Patrick ...              GSW
# 870134   Ty Jerome, Anthony Lamb, Patrick Baldwin Jr., ...              GSW
# 568273   Ty Jerome, Patrick Baldwin Jr., Stephen Curry,...              GSW
# 1171521  Jordan Poole, James Wiseman, Jonathan Kuminga,...              GSW
# 1472971  Jordan Poole, Jonathan Kuminga, Anthony Lamb, ...              GSW
# 568375   Jordan Poole, Patrick Baldwin Jr., Stephen Cur...              GSW
# 1171352  James Wiseman, Jonathan Kuminga, Moses Moody, ...              GSW
# 1171358  James Wiseman, Anthony Lamb, Moses Moody, Patr...              GSW
# 1171351  Jonathan Kuminga, Anthony Lamb, Moses Moody, P...              GSW
# 1171334  Jonathan Kuminga, Anthony Lamb, Moses Moody, P...              GSW
#
#         SeasonName  SeasonEndYr      SeasonType  SecondsPlayed       Player  \
# 1473124    2022-23         2023  Regular Season          104.0   PlayerFive
# 1171363    2022-23         2023  Regular Season          420.0   PlayerFour
# 1472930    2022-23         2023  Regular Season          332.0   PlayerFive
# 1472997    2022-23         2023  Regular Season          223.0   PlayerFive
# 1473156    2022-23         2023  Regular Season           81.0   PlayerFive
# 1171630    2022-23         2023  Regular Season           77.0   PlayerFour
# 1171403    2022-23         2023  Regular Season          314.0   PlayerFour
# 1473148    2022-23         2023  Regular Season           88.0   PlayerFive
# 1473099    2022-23         2023  Regular Season          129.0   PlayerFive
# 1472893    2022-23         2023  Regular Season          426.0   PlayerFive
# 1472949    2022-23         2023  Regular Season          285.0   PlayerFive
# 1171489    2022-23         2023  Regular Season          200.0   PlayerFour
# 1473159    2022-23         2023  Regular Season           80.0   PlayerFive
# 870064     2022-23         2023  Regular Season           81.0  PlayerThree
# 1473189    2022-23         2023  Regular Season           61.0   PlayerFive
# 1171436    2022-23         2023  Regular Season          259.0   PlayerFour
# 1171396    2022-23         2023  Regular Season          336.0   PlayerFour
# 1171467    2022-23         2023  Regular Season          223.0   PlayerFour
# 1473160    2022-23         2023  Regular Season           79.0   PlayerFive
# 1171712    2022-23         2023  Regular Season           28.0   PlayerFour
# 1171549    2022-23         2023  Regular Season          139.0   PlayerFour
# 1171565    2022-23         2023  Regular Season          131.0   PlayerFour
# 1171700    2022-23         2023  Regular Season           38.0   PlayerFour
# 869978     2022-23         2023  Regular Season          151.0  PlayerThree
# 870076     2022-23         2023  Regular Season           74.0  PlayerThree
# 1473149    2022-23         2023  Regular Season           88.0   PlayerFive
# 1171588    2022-23         2023  Regular Season          109.0   PlayerFour
# 1171671    2022-23         2023  Regular Season           54.0   PlayerFour
# 1473023    2022-23         2023  Regular Season          200.0   PlayerFive
# 1171422    2022-23         2023  Regular Season          276.0   PlayerFour
# 1171574    2022-23         2023  Regular Season          121.0   PlayerFour
# 1171512    2022-23         2023  Regular Season          177.0   PlayerFour
# 869921     2022-23         2023  Regular Season          209.0  PlayerThree
# 1472904    2022-23         2023  Regular Season          393.0   PlayerFive
# 568564     2022-23         2023  Regular Season           50.0    PlayerTwo
# 1473171    2022-23         2023  Regular Season           73.0   PlayerFive
# 1473070    2022-23         2023  Regular Season          152.0   PlayerFive
# 1171354    2022-23         2023  Regular Season          456.0   PlayerFour
# 1171535    2022-23         2023  Regular Season          157.0   PlayerFour
# 1171339    2022-23         2023  Regular Season          501.0   PlayerFour
# 1171479    2022-23         2023  Regular Season          211.0   PlayerFour
# 869979     2022-23         2023  Regular Season          150.0  PlayerThree
# 870118     2022-23         2023  Regular Season           52.0  PlayerThree
# 1473006    2022-23         2023  Regular Season          215.0   PlayerFive
# 1472889    2022-23         2023  Regular Season          439.0   PlayerFive
# 1171548    2022-23         2023  Regular Season          141.0   PlayerFour
# 1472791    2022-23         2023  Regular Season         1409.0   PlayerFive
# 1171437    2022-23         2023  Regular Season          259.0   PlayerFour
# 1171605    2022-23         2023  Regular Season           96.0   PlayerFour
# 1171507    2022-23         2023  Regular Season          182.0   PlayerFour
# 870134     2022-23         2023  Regular Season           43.0  PlayerThree
# 568273     2022-23         2023  Regular Season          357.0    PlayerTwo
# 1171521    2022-23         2023  Regular Season          170.0   PlayerFour
# 1472971    2022-23         2023  Regular Season          257.0   PlayerFive
# 568375     2022-23         2023  Regular Season          200.0    PlayerTwo
# 1171352    2022-23         2023  Regular Season          460.0   PlayerFour
# 1171358    2022-23         2023  Regular Season          439.0   PlayerFour
# 1171351    2022-23         2023  Regular Season          461.0   PlayerFour
# 1171334    2022-23         2023  Regular Season          539.0   PlayerFour
#
#                   PlayerName player_name season  player_height
# 1473124  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171363  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472930  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472997  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473156  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171630  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171403  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473148  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473099  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472893  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472949  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171489  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473159  Patrick Baldwin Jr.         NaN    NaN            NaN
# 870064   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473189  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171436  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171396  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171467  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473160  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171712  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171549  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171565  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171700  Patrick Baldwin Jr.         NaN    NaN            NaN
# 869978   Patrick Baldwin Jr.         NaN    NaN            NaN
# 870076   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473149  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171588  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171671  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473023  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171422  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171574  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171512  Patrick Baldwin Jr.         NaN    NaN            NaN
# 869921   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472904  Patrick Baldwin Jr.         NaN    NaN            NaN
# 568564   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473171  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473070  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171354  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171535  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171339  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171479  Patrick Baldwin Jr.         NaN    NaN            NaN
# 869979   Patrick Baldwin Jr.         NaN    NaN            NaN
# 870118   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1473006  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472889  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171548  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472791  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171437  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171605  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171507  Patrick Baldwin Jr.         NaN    NaN            NaN
# 870134   Patrick Baldwin Jr.         NaN    NaN            NaN
# 568273   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171521  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1472971  Patrick Baldwin Jr.         NaN    NaN            NaN
# 568375   Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171352  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171358  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171351  Patrick Baldwin Jr.         NaN    NaN            NaN
# 1171334  Patrick Baldwin Jr.         NaN    NaN            NaN
